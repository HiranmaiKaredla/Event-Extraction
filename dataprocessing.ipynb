# %%
import os
import json
import pandas as pd
from xml.etree import ElementTree

# %%
# !pwd
# Out:
# /scratch/hkaredla/Event-Extraction

# %%
def get_file_paths():
    df = pd.read_csv('/scratch/hkaredla/Event-Extraction/data/data_list.csv')
    types = df['type'].unique()
    train, valid, test = [], [], []
    
    for i in range(len(df)):
        path = os.path.join( '/scratch/hkaredla/Event-Extraction/data/English/English', df['path'].iloc[i] + '.apf.xml')
        if df['type'].iloc[i] == 'train':
            train.append(path)
        elif df['type'].iloc[i] == 'valid':
            valid.append(path)
        elif df['type'].iloc[i] == 'test':
            test.append(path)
        
    return train, valid, test

# %%
class Parser:
    def __init__(self, xml_path):
        self.entity_mentions = []
        self.event_mentions = []
        self.parse(xml_path)
        
    def parse(self, xml_path):
        tree = ElementTree.parse(xml_path)
        root = tree.getroot()
        #print(tree)
        #print(root)
        
        for child in root[0]:
            if child.tag == 'entity':
                self.entity_mentions.extend(self.parse_entity_tag(child))
            elif child.tag in ['value', 'timex2']:
                self.entity_mentions.extend(self.parse_value_timex(child))
            elif child.tag == 'event':
                self.event_mentions.extend(self.parse_event_tag(child))
                
     
    def parse_entity_tag(self, node):
        entity_mentions = []
        for child in node:
            if child.tag != 'entity_mention':  
                continue
            extent = child[0]
            charset = extent[0]

            entity_mention = dict()
            entity_mention['entity_id'] = child.attrib['ID']
            entity_mention['entity_type'] = '{}:{}'.format(node.attrib['TYPE'], node.attrib['SUBTYPE'])
            entity_mention['text'] = charset.text
            entity_mention['position'] = (int(charset.attrib['START']), int(charset.attrib['END']))

            entity_mentions.append(entity_mention)
        return entity_mentions
    
    def parse_event_tag(self, node):
        event_mentions = []
        for child in node:
            if child.tag == 'event_mention':
                event_mention = dict()
                event_mention['event_type'] = '{}:{}'.format(node.attrib['TYPE'], node.attrib['SUBTYPE'])
                event_mention['arguments'] = []
                for child2 in child:
                    if child2.tag == 'ldc_scope':
                        charset = child2[0]
                        event_mention['text'] = charset.text
                        event_mention['position'] = (int(charset.attrib['START']), int(charset.attrib['END']))
                    if child2.tag == 'anchor':
                        charset = child2[0]
                        event_mention['trigger'] = charset.text
                    if child2.tag == 'event_mention_argument':
                        extent = child2[0]
                        charset = extent[0]
                        event_mention['arguments'].append({
                            'text': charset.text,
                            'role': child2.attrib['ROLE'],
                            'entity_id': child2.attrib['REFID']
                        })
                event_mentions.append(event_mention)
        return event_mentions

                                            
    def parse_value_timex(self, node):
        entity_mentions = []

        for child in node:
            extent = child[0]
            charset = extent[0]

            entity_mention = dict()
            entity_mention['entity_id'] = child.attrib['ID']

            if 'TYPE' in node.attrib:
                entity_mention['entity_type'] = node.attrib['TYPE']
            if 'SUBTYPE' in node.attrib:
                entity_mention['entity_type'] += ':{}'.format(node.attrib['SUBTYPE'])
            if child.tag == 'timex2_mention':
                entity_mention['entity_type'] = 'TIM:time'

            entity_mention['text'] = charset.text
            entity_mention['position'] = (int(charset.attrib['START']), int(charset.attrib['END']))

            entity_mentions.append(entity_mention)

        return entity_mentions
    
    
    def get_data(self):
        data = []
#         print(len(self.entity_mentions))
        #print(len(self.event_mentions))
        for event_mention in self.event_mentions:
            item = dict()
            #print(event_mention)
            item['sentence'] = event_mention['text']

            entity_map = dict()
            item['golden_entity_mentions'] = []
            text_position = event_mention['position']
            for entity_mention in self.entity_mentions:
                entity_position = entity_mention['position']
                if text_position[0] <= entity_position[0] and entity_position[1] <= text_position[1]:
                    item['golden_entity_mentions'].append({
                        'text': entity_mention['text'],
                        'entity_type': entity_mention['entity_type']
                    })
                    entity_map[entity_mention['entity_id']] = entity_mention

            event_arguments = []
            print("2")
            for argument in event_mention['arguments']:
                event_arguments.append({
                    'role': argument['role'],
                    'entity_type': entity_map[argument['entity_id']]['entity_type'],
                    'text': argument['text'],
                })

            item['golden_event_mention'] = {
                'trigger': event_mention['trigger'],
                'arguments': event_arguments,
                'event_type': event_mention['event_type'],
            }
            
            data.append(item)
        return data

# %%
def preprocessing(data_type, file_path_list):
    data = []
    
    for filename in file_path_list:
        #Parser(filename)
        x = Parser(filename).get_data()
        data.extend(x)
    #print(len(data))
    with open('/scratch/hkaredla/Event-Extraction/data/output/{}.json'.format(data_type),'w') as f:
        json.dump(data, f, indent=2)

# %%
train_files, valid_files, test_files = get_file_paths()

# %%
#preprocessing('train', train_files)

# %%
preprocessing('train', train_files)
preprocessing('valid', valid_files)
preprocessing('test', test_files)
# Out:
# {'event_type': 'Movement:Transport', 'arguments': [{'text': 'a 30-foot Cuban patrol boat with four heavily armed men', 'role': 'Vehicle', 'entity_id': 'CNN_CF_20030303.1900.00-E96-192'}, {'text': 'four heavily armed men', 'role': 'Artifact', 'entity_id': 'CNN_CF_20030303.1900.00-E98-194'}, {'text': 'American shores', 'role': 'Destination', 'entity_id': 'CNN_CF_20030303.1900.00-E99-195'}], 'text': 'Even as the\nsecretary of homeland security was putting his people on high alert last\nmonth, a 30-foot Cuban patrol boat with four heavily armed men landed on\nAmerican shores, utterly undetected by the Coast Guard Secretary Ridge\nnow leads', 'position': (277, 514), 'trigger': 'landed'}
# 2
# {'event_type': 'Movement:Transport', 'arguments': [{'text': 'four armed Cubans', 'role': 'Artifact', 'entity_id': 'CNN_CF_20030303.1900.00-E98-70'}, {'text': 'these\nbozos', 'role': 'Agent', 'entity_id': 'CNN_CF_20030303.1900.00-E4-69'}, {'text': 'our shores', 'role': 'Destination', 'entity_id': 'CNN_CF_20030303.1900.00-E99-71'}], 'text': "And these\nbozos let four armed Cubans land on our shores when they're trying to\nmake a high terrorist alert", 'position': (1827, 1933), 'trigger': 'land'}
# 2
# {'event_type': 'Personnel:Elect', 'arguments': [{'text': 'a dead man', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.00-E10-13'}], 'text': 'He\nlost an election to a dead man', 'position': (719, 751), 'trigger': 'election'}
# 2
# {'event_type': 'Personnel:Elect', 'arguments': [{'text': 'who', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.00-E22-36'}, {'text': 'public office', 'role': 'Position', 'entity_id': 'CNN_CF_20030303.1900.00-V2-1'}], 'text': 'Paul, as I understand your definition of a political -- of a professional\npolitician based on that is somebody who is elected to public office', 'position': (1141, 1282), 'trigger': 'elected'}
# 2
# {'event_type': 'Personnel:Start-Position', 'arguments': [{'text': 'professionals', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.00-E6-79'}], 'text': 'Hire professionals, Mr. President', 'position': (2017, 2049), 'trigger': 'Hire'}
# 2
# {'event_type': 'Personnel:Start-Position', 'arguments': [{'text': 'Democratic career politicians', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.00-E57-90'}, {'text': 'the Pentagon', 'role': 'Entity', 'entity_id': 'CNN_CF_20030303.1900.00-E54-92'}, {'text': 'the Justice Department', 'role': 'Entity', 'entity_id': 'CNN_CF_20030303.1900.00-E53-93'}], 'text': "It's OK to put\nDemocratic career politicians at the Pentagon and the Justice Department\nif they're Democrats but not if they're Republicans, is that right", 'position': (2270, 2423), 'trigger': 'put'}
# 2
# {'event_type': 'Personnel:Nominate', 'arguments': [{'text': 'the 10th candidate for the nomination', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.00-E60-97'}], 'text': 'Senator Christopher Dodd of Connecticut made the announcement today\nthat he would not be the 10th candidate for the nomination', 'position': (2735, 2860), 'trigger': 'nomination'}
# 2
# {'event_type': 'Personnel:Nominate', 'arguments': [], 'text': 'He explained he could better spend the next two years on\nhomeland security, the economy and judicial nominations', 'position': (2961, 3072), 'trigger': 'nominations'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'we', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030303.1900.00-E3-141'}, {'text': 'Iraq', 'role': 'Place', 'entity_id': 'CNN_CF_20030303.1900.00-E75-142'}], 'text': 'It could swell to as\nmuch as $500 billion if we go to war in Iraq', 'position': (3771, 3835), 'trigger': 'war'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'two\nmillion Americans', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.00-E70-126'}], 'text': 'In all, two\nmillion Americans have lost their jobs under President Bush so far, not\nto mention three of them being the top three leaders of his economic\nteam', 'position': (3568, 3724), 'trigger': 'lost t'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'Former Arkansas Governor and U.S. Senator Dale Bumpers', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.05-E11-1'}, {'text': 'Arkansas', 'role': 'Entity', 'entity_id': 'CNN_CF_20030303.1900.05-E84-145'}, {'text': 'U.S', 'role': 'Entity', 'entity_id': 'CNN_CF_20030303.1900.05-E95-247'}, {'text': 'Arkansas Governor', 'role': 'Position', 'entity_id': 'CNN_CF_20030303.1900.05-V2-1'}, {'text': 'Senator', 'role': 'Position', 'entity_id': 'CNN_CF_20030303.1900.05-V3-1'}], 'text': 'Former Arkansas Governor and U.S. Senator Dale Bumpers has just published\na memoir called "The Best Lawyer in a One-Lawyer Town', 'position': (148, 274), 'trigger': 'Former'}
# 2
# {'event_type': 'Contact:Meet', 'arguments': [{'text': 'his ranch', 'role': 'Place', 'entity_id': 'CNN_CF_20030303.1900.05-E4-35'}, {'text': 'you', 'role': 'Entity', 'entity_id': 'CNN_CF_20030303.1900.05-E11-255'}, {'text': 'President Lyndon Johnson', 'role': 'Entity', 'entity_id': 'CNN_CF_20030303.1900.05-E2-30'}], 'text': 'You cite a session you had\nwith President Lyndon Johnson in Austin, I guess, at his ranch, right', 'position': (508, 603), 'trigger': 'session'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'I', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.05-E2-39'}, {'text': 'majority\nleader', 'role': 'Position', 'entity_id': 'CNN_CF_20030303.1900.05-V4-1'}], 'text': 'When I was majority\nleader, and later president, I spent all my time pulling every power\nstring I could find to pull, trying to pass bills that helped people', 'position': (660, 816), 'trigger': 'was'}
# 2
# {'event_type': 'Life:Marry', 'arguments': [{'text': 'everybody', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.05-E27-107'}, {'text': 'Betty', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.05-E30-110'}], 'text': "And I've said many times, if we all agreed on everything,\neverybody would want to marry Betty and we would really be in a mess,\nwouldn't we, Bob", 'position': (2976, 3119), 'trigger': 'marry'}
# 2
# {'event_type': 'Personnel:Elect', 'arguments': [{'text': 'president', 'role': 'Entity', 'entity_id': 'CNN_CF_20030303.1900.05-E55-165'}, {'text': 'Franklin Roosevelt', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.05-E55-164'}], 'text': 'Bob, I think that the reason everybody in the south -- you know, first of\nall, we were -- when Franklin Roosevelt was elected president, we had\nbeen living what we thought was still a conquered nation after the Civil\nWar', 'position': (3899, 4118), 'trigger': 'elected'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'Bob, I think that the reason everybody in the south -- you know, first of\nall, we were -- when Franklin Roosevelt was elected president, we had\nbeen living what we thought was still a conquered nation after the Civil\nWar', 'position': (3899, 4118), 'trigger': 'Civil\nWar'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "And from that\ntime on, that's the reason we had 22 Democratic senators from 11\nconfederate states, is because of the Civil War and because of what we\nthought was a heavy hand of the federal government all the time", 'position': (4245, 4457), 'trigger': 'Civil War'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'A million and a\nhalf veterans came out of War World II on the GI bill and got that kind\nof an education', 'position': (5549, 5651), 'trigger': 'War World II'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'I', 'role': 'Person', 'entity_id': 'CNN_CF_20030303.1900.05-E11-5'}], 'text': 'I knew it was time to\nleave', 'position': (1779, 1805), 'trigger': 'leave'}
# 2
# {'event_type': 'Movement:Transport', 'arguments': [{'text': 'I', 'role': 'Artifact', 'entity_id': 'CNN_CF_20030303.1900.05-E15-112'}, {'text': 'the Associated Press', 'role': 'Agent', 'entity_id': 'CNN_CF_20030303.1900.05-E33-118'}, {'text': 'Washington', 'role': 'Destination', 'entity_id': 'CNN_CF_20030303.1900.05-E32-117'}, {'text': '45 years ago', 'role': 'Time-At-Beginning', 'entity_id': 'CNN_CF_20030303.1900.05-T14-1'}], 'text': 'Senator Bumpers, of the 22 senators of the old confederacy, when I got to\nWashington with the Associated Press, 45 years ago, 22 of them were\nDemocrats, nine were Republicans', 'position': (3132, 3305), 'trigger': 'got'}
# 2
# {'event_type': 'Contact:Phone-Write', 'arguments': [{'text': 'I', 'role': 'Entity', 'entity_id': 'CNN_CF_20030303.1900.06-1-E27-72'}], 'text': "I'm chewing gum and talking on the phone while writing this note", 'position': (429, 492), 'trigger': 'talking'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'the al Qaeda chief operations\nofficer', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030303.1900.06-1-E1-49'}, {'text': 'Bush', 'role': 'Target', 'entity_id': 'CNN_CF_20030303.1900.06-1-E3-14'}], 'text': 'Bush should torture the al Qaeda chief operations\nofficer', 'position': (750, 806), 'trigger': 'torture'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [{'text': 'Mr. Begala', 'role': 'Giver', 'entity_id': 'CNN_CF_20030303.1900.06-1-E12-28'}, {'text': 'Mr. Carville', 'role': 'Giver', 'entity_id': 'CNN_CF_20030303.1900.06-1-E13-30'}], 'text': "If the budget goes through as is, why don't\nMr. Begala and Mr. Carville just donate the extra tax money they don't\nwant", 'position': (1104, 1222), 'trigger': 'donate'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [{'text': 'I', 'role': 'Giver', 'entity_id': 'CNN_CF_20030303.1900.06-1-E12-38'}, {'text': 'the Democrats', 'role': 'Recipient', 'entity_id': 'CNN_CF_20030303.1900.06-1-E16-39'}], 'text': "I'll donate to the Democrats", 'position': (1353, 1380), 'trigger': 'donate'}
# 2
# {'event_type': 'Justice:Sue', 'arguments': [{'text': 'he', 'role': 'Plaintiff', 'entity_id': 'CNN_CF_20030303.1900.06-1-E3-51'}], 'text': "He had to sue to become our\npresident, and he keeps trying to bribe other countries' democratic\ngovernments into his supporting his agenda", 'position': (1541, 1678), 'trigger': 'sue'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'the\nU.S', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030303.1900.06-2-E18-49'}, {'text': 'Iraq', 'role': 'Place', 'entity_id': 'CNN_CF_20030303.1900.06-2-E19-50'}], 'text': 'And now how are people going to argue that the\nU.S. can no longer both fight a war with Iraq and also fight terrorism,\nspecifically al Qaeda', 'position': (302, 441), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'We', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030303.1900.06-2-E18-7'}, {'text': 'Iraq', 'role': 'Place', 'entity_id': 'CNN_CF_20030303.1900.06-2-E19-8'}], 'text': 'We go to war in Iraq, 200,000\npeople start protesting in Pakistan, they put too much pressure on the\ngovernment', 'position': (703, 813), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'We', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030303.1900.06-2-E18-16'}, {'text': 'Iraq', 'role': 'Place', 'entity_id': 'CNN_CF_20030303.1900.06-2-E19-17'}], 'text': 'We go to war in Iraq, it would be the\nworst thing we can do', 'position': (911, 969), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "What I can't stand is a president who is going to screw up our war\nagainst terrorism when I thought that was his job", 'position': (1102, 1217), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Demonstrate', 'arguments': [{'text': 'Pakistan', 'role': 'Place', 'entity_id': 'CNN_CF_20030303.1900.06-2-E2-10'}, {'text': '200,000\npeople', 'role': 'Entity', 'entity_id': 'CNN_CF_20030303.1900.06-2-E1-9'}], 'text': 'We go to war in Iraq, 200,000\npeople start protesting in Pakistan, they put too much pressure on the\ngovernment', 'position': (703, 813), 'trigger': 'protesting'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "What I can't stand is a president who is going to screw up our war\nagainst terrorism when I thought that was his job", 'position': (1102, 1217), 'trigger': 'terrorism'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'And now how are people going to argue that the\nU.S. can no longer both fight a war with Iraq and also fight terrorism,\nspecifically al Qaeda', 'position': (302, 441), 'trigger': 'terrorism'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [{'text': 'they', 'role': 'Recipient', 'entity_id': 'CNN_CF_20030304.1900.02-E59-130'}], 'text': 'If harmed by a doc, they ought to be able to recover their economic\ncosts, economic losses', 'position': (4991, 5080), 'trigger': 'harmed'}
# 2
# {'event_type': 'Justice:Sue', 'arguments': [], 'text': "Let\nme set aside the hypocrisy of a man who became president because of a\nlawsuit trying to eliminate everybody else's lawsuits, but instead focus\non his own experience", 'position': (696, 863), 'trigger': 'lawsuit'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [{'text': 'all of the victims that get a little money', 'role': 'Recipient', 'entity_id': 'CNN_CF_20030304.1900.02-E39-77'}], 'text': 'And the\nentire pay-out to all of the victims that get a little money, not the 90\npercent who never file a claim, amounts to less than what we spend on dog\nfood', 'position': (2831, 2989), 'trigger': 'pay-out'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [{'text': '$5.4 billion', 'role': 'Money', 'entity_id': 'CNN_CF_20030304.1900.02-V3-1'}], 'text': "It's about $5.4 billion is the pay-out", 'position': (3005, 3042), 'trigger': 'pay-out'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [], 'text': 'payoffs have been stable, adjusted for inflation, National\nPractitioners Databank', 'position': (4448, 4528), 'trigger': 'payoffs'}
# 2
# {'event_type': 'Business:End-Org', 'arguments': [{'text': 'the country', 'role': 'Place', 'entity_id': 'CNN_CF_20030304.1900.02-E95-274'}], 'text': 'Both the AMA and the Bush administration released reports\nthis week saying out of control trial lawyers are driving doctors out of\ntheir practices all across the country', 'position': (195, 363), 'trigger': 'driving'}
# 2
# {'event_type': 'Justice:Sue', 'arguments': [{'text': 'the patient', 'role': 'Plaintiff', 'entity_id': 'CNN_CF_20030304.1900.02-E97-277'}], 'text': 'President Bush points this way\ntoday, even the most frivolous of lawsuits cost money, premiums go up and\neither way, the patient pays', 'position': (366, 498), 'trigger': 'lawsuits'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [{'text': '$250,000', 'role': 'Money', 'entity_id': 'CNN_CF_20030304.1900.02-V9-1'}, {'text': 'someone who had a double mastectomy', 'role': 'Recipient', 'entity_id': 'CNN_CF_20030304.1900.02-E61-134'}, {'text': "an infant\nwho's brain-damaged and has no economic loss", 'role': 'Recipient', 'entity_id': 'CNN_CF_20030304.1900.02-E62-136'}], 'text': "Tell someone who had a double mastectomy, tell an infant\nwho's brain-damaged and has no economic loss that for the rest of their\nlives they're going to get dribbled out $250,000 for their entire life\nexpectancy", 'position': (5350, 5559), 'trigger': 'dribbled'}
# 2
# {'event_type': 'Personnel:Elect', 'arguments': [{'text': 'president', 'role': 'Position', 'entity_id': 'CNN_CF_20030304.1900.02-V1-1'}], 'text': "Let\nme set aside the hypocrisy of a man who became president because of a\nlawsuit trying to eliminate everybody else's lawsuits, but instead focus\non his own experience", 'position': (696, 863), 'trigger': 'became'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [{'text': 'they', 'role': 'Recipient', 'entity_id': 'CNN_CF_20030304.1900.02-E59-130'}], 'text': 'If harmed by a doc, they ought to be able to recover their economic\ncosts, economic losses', 'position': (4991, 5080), 'trigger': 'recover'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [{'text': '10 million', 'role': 'Money', 'entity_id': 'CNN_CF_20030304.1900.02-V12-1'}, {'text': '20 million', 'role': 'Money', 'entity_id': 'CNN_CF_20030304.1900.02-V13-1'}, {'text': '$30\nmillion', 'role': 'Money', 'entity_id': 'CNN_CF_20030304.1900.02-V14-1'}], 'text': 'There are awards in 10 million, 20 million, $30\nmillion in California for economic', 'position': (6154, 6235), 'trigger': 'awards'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'who', 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.02-E16-33'}, {'text': 'the agency that pledges to\nprotect the public', 'role': 'Entity', 'entity_id': 'CNN_CF_20030304.1900.02-E13-30'}, {'text': 'surgeons', 'role': 'Position', 'entity_id': 'CNN_CF_20030304.1900.02-V17-1'}], 'text': 'Here\'s what the "Dallas Morning News" reported recently: "The\nTexas State Board of Medical Examiners, the agency that pledges to\nprotect the public has granted second and third chances to surgeons who\nare thrown out of hospitals because they botched operations', 'position': (1064, 1323), 'trigger': 'thrown out'}
# 2
# {'event_type': 'Justice:Sue', 'arguments': [], 'text': "Actually, Troy Brennan, the same doctor at Harvard Public School of\nHealth said the issue is not to fuel lawsuits, it's too many", 'position': (2555, 2682), 'trigger': 'lawsuits'}
# 2
# {'event_type': 'Life:Injure', 'arguments': [{'text': 'the victims of medical malpractice', 'role': 'Victim', 'entity_id': 'CNN_CF_20030304.1900.02-E38-75'}], 'text': "Less than\n10 percent of the victims of medical malpractice, and we're talking about\nhorrific injuries here, even file a claim", 'position': (2685, 2809), 'trigger': 'injuries'}
# 2
# {'event_type': 'Justice:Sue', 'arguments': [{'text': 'everybody else', 'role': 'Plaintiff', 'entity_id': 'CNN_CF_20030304.1900.02-E6-11'}], 'text': "Let\nme set aside the hypocrisy of a man who became president because of a\nlawsuit trying to eliminate everybody else's lawsuits, but instead focus\non his own experience", 'position': (696, 863), 'trigger': 'lawsuits'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'a single doctor', 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.02-E20-43'}, {'text': 'doctor', 'role': 'Position', 'entity_id': 'CNN_CF_20030304.1900.02-V18-1'}, {'text': 'the last five\nyears', 'role': 'Time-Within', 'entity_id': 'CNN_CF_20030304.1900.02-T1-1'}], 'text': 'It has refused in the last five\nyears to revoke the license of a single doctor for committing medical\nerrors', 'position': (1444, 1551), 'trigger': 'revoke'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'them', 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.02-E28-57'}, {'text': 'doctors', 'role': 'Position', 'entity_id': 'CNN_CF_20030304.1900.02-V19-1'}], 'text': 'If there are any bad\ndoctors we want them removed from the practice of medicine', 'position': (1918, 1996), 'trigger': 'removed'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'Doctors', 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.02-E44-94'}, {'text': 'Doctors', 'role': 'Position', 'entity_id': 'CNN_CF_20030304.1900.02-V20-1'}], 'text': 'Doctors are leaving practice because of insurance premium, right', 'position': (3472, 3535), 'trigger': 'leaving'}
# 2
# {'event_type': 'Life:Injure', 'arguments': [{'text': 'a bad doctor', 'role': 'Agent', 'entity_id': 'CNN_CF_20030304.1900.02-E71-95'}, {'text': 'people\nwho have been harmed by a bad doctor', 'role': 'Victim', 'entity_id': 'CNN_CF_20030304.1900.02-E59-125'}], 'text': "Well, let's look at what the president is actually proposing for people\nwho have been harmed by a bad doctor", 'position': (4806, 4913), 'trigger': 'harmed'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [], 'text': "Seventy percent of the cases filed are told there's no payment", 'position': (7458, 7519), 'trigger': 'payment'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [{'text': 'someone', 'role': 'Giver', 'entity_id': 'CNN_CF_20030304.1900.02-E29-59'}], 'text': "Because someone pays money in a case, the insurance\ncompany may pay money because they're afraid there's is going to be a\ngiant award in this case because of this broken liability system", 'position': (2158, 2343), 'trigger': 'pays'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "But here in Washington, President Bush says it's all a hoax, and many\nbelieve he has already made up his mind to go to war", 'position': (398, 519), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "Congressman Sanders, you're opposed to this war", 'position': (673, 719), 'trigger': 'war'}
# 2
# {'event_type': 'Life:Die', 'arguments': [{'text': 'the American men and women', 'role': 'Victim', 'entity_id': 'CNN_CF_20030304.1900.04-E67-218'}, {'text': 'the American men and women', 'role': 'Victim', 'entity_id': 'CNN_CF_20030304.1900.04-E68-219'}], 'text': "When the guns begin to fire,\nwhen the American men and women are in harm's way and may be dying, is\nthat now the time for you and your allies to shut up and support the\ntroops", 'position': (787, 961), 'trigger': 'dying'}
# 2
# {'event_type': 'Life:Die', 'arguments': [{'text': 'tens and thousands of Iraqi\nwomen and children', 'role': 'Victim', 'entity_id': 'CNN_CF_20030304.1900.04-E16-30'}, {'text': 'tens and thousands of Iraqi\nwomen and children', 'role': 'Victim', 'entity_id': 'CNN_CF_20030304.1900.04-E17-31'}], 'text': "Well it's not -- are you suggesting that when tens and thousands of Iraqi\nwomen and children are killed, and when young men and women in this\ncountry are unnecessarily put at harm's risk, what should we do", 'position': (987, 1191), 'trigger': 'killed'}
# 2
# {'event_type': 'Life:Injure', 'arguments': [], 'text': "And obviously we're going to pray that there's fewer\ncasualties", 'position': (1288, 1350), 'trigger': 'casualties'}
# 2
# {'event_type': 'Conflict:Demonstrate', 'arguments': [{'text': 'you', 'role': 'Entity', 'entity_id': 'CNN_CF_20030304.1900.04-E6-44'}, {'text': 'the streets', 'role': 'Place', 'entity_id': 'CNN_CF_20030304.1900.04-E23-23'}], 'text': 'Are you going to demonstrate against them in the streets', 'position': (1365, 1420), 'trigger': 'demonstrate'}
# 2
# {'event_type': 'Conflict:Demonstrate', 'arguments': [{'text': 'I', 'role': 'Entity', 'entity_id': 'CNN_CF_20030304.1900.04-E6-46'}], 'text': "No, I don't demonstrate against anybody during a war", 'position': (1435, 1486), 'trigger': 'demonstrate'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "No, I don't demonstrate against anybody during a war", 'position': (1435, 1486), 'trigger': 'war'}
# 2
# {'event_type': 'Life:Die', 'arguments': [{'text': 'over a million of his own\ncitizens', 'role': 'Victim', 'entity_id': 'CNN_CF_20030304.1900.04-E43-113'}, {'text': 'Saddam Hussein', 'role': 'Agent', 'entity_id': 'CNN_CF_20030304.1900.04-E30-111'}], 'text': 'What I do know is Saddam Hussein has butchered over a million of his own\ncitizens', 'position': (3206, 3286), 'trigger': 'butchered'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'him', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030304.1900.04-E30-123'}], 'text': 'Furthermore, the United States supported him in the war against Iran', 'position': (3606, 3673), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "What we're talking about is the unpredictable nature of war and what\ncould happen in this war", 'position': (3829, 3921), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "What we're talking about is the unpredictable nature of war and what\ncould happen in this war", 'position': (3829, 3921), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'the most\npowerful nation on Earth', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030304.1900.04-E12-173'}, {'text': 'a Muslim nation', 'role': 'Place', 'entity_id': 'CNN_CF_20030304.1900.04-E45-244'}], 'text': "You don't know what happens when the most\npowerful nation on Earth invades and occupies a Muslim nation and kills\ntens of thousands of people", 'position': (4900, 5040), 'trigger': 'invades'}
# 2
# {'event_type': 'Life:Die', 'arguments': [{'text': 'tens of thousands of people', 'role': 'Victim', 'entity_id': 'CNN_CF_20030304.1900.04-E56-178'}, {'text': 'the most\npowerful nation on Earth', 'role': 'Agent', 'entity_id': 'CNN_CF_20030304.1900.04-E12-173'}, {'text': 'a Muslim nation', 'role': 'Place', 'entity_id': 'CNN_CF_20030304.1900.04-E45-244'}], 'text': "You don't know what happens when the most\npowerful nation on Earth invades and occupies a Muslim nation and kills\ntens of thousands of people", 'position': (4900, 5040), 'trigger': 'kills'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "I'm not crazy about it\nmyself", 'position': (722, 750), 'trigger': 'it'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'those\nwho would wage war', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030304.1900.04-E42-104'}], 'text': "No, it's so important -- you know this -- and I know it's fun and we love\ndoing partisan Punch & Judy, but is there ever a time when we stand up\neven if we respectfully disagree with the commander in chief and those\nwho would wage war", 'position': (2762, 2995), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'Ayatollah Khomeini', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030304.1900.04-E47-131'}, {'text': 'Iran', 'role': 'Place', 'entity_id': 'CNN_CF_20030304.1900.04-E45-130'}, {'text': 'the Shah', 'role': 'Target', 'entity_id': 'CNN_CF_20030304.1900.04-E50-134'}], 'text': 'For example -- wait a second -- in Iran, the\nreason that you had Ayatollah Khomeini in power is he overthrew the Shah', 'position': (3924, 4040), 'trigger': 'overthrew'}
# 2
# {'event_type': 'Personnel:Start-Position', 'arguments': [{'text': 'the Shah', 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.04-E50-136'}, {'text': 'the Shah', 'role': 'Position', 'entity_id': 'CNN_CF_20030304.1900.04-V2-1'}], 'text': 'You who put the Shah in power', 'position': (4043, 4071), 'trigger': 'put'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'he', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030304.1900.04-E47-145'}, {'text': 'the\nguy who he overthrew', 'role': 'Target', 'entity_id': 'CNN_CF_20030304.1900.04-E50-143'}], 'text': 'But the problem with Khomeini was that the\nguy who he overthrew was put in power by the United States', 'position': (4215, 4315), 'trigger': 'overthrew'}
# 2
# {'event_type': 'Personnel:Start-Position', 'arguments': [{'text': 'the\nguy who he overthrew', 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.04-E50-143'}, {'text': 'the United States', 'role': 'Entity', 'entity_id': 'CNN_CF_20030304.1900.04-E12-146'}], 'text': 'But the problem with Khomeini was that the\nguy who he overthrew was put in power by the United States', 'position': (4215, 4315), 'trigger': 'put in power'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'We', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030304.1900.04-E12-147'}], 'text': 'We overthrew (UNINTELLIGIBLE) and put the Shah of Iran in power', 'position': (4361, 4423), 'trigger': 'overthrew'}
# 2
# {'event_type': 'Personnel:Start-Position', 'arguments': [{'text': 'the Shah of Iran', 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.04-E50-148'}, {'text': 'Iran', 'role': 'Place', 'entity_id': 'CNN_CF_20030304.1900.04-E45-149'}, {'text': 'We', 'role': 'Entity', 'entity_id': 'CNN_CF_20030304.1900.04-E12-147'}, {'text': 'the Shah of Iran', 'role': 'Position', 'entity_id': 'CNN_CF_20030304.1900.04-V3-1'}], 'text': 'We overthrew (UNINTELLIGIBLE) and put the Shah of Iran in power', 'position': (4361, 4423), 'trigger': 'put'}
# 2
# {'event_type': 'Personnel:Start-Position', 'arguments': [{'text': 'him', 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.04-E50-155'}, {'text': 'the CIA', 'role': 'Entity', 'entity_id': 'CNN_CF_20030304.1900.04-E52-154'}], 'text': "But I mean you're attacking the CIA for putting him in, when it was --\nthe problem was Khomeini", 'position': (4476, 4570), 'trigger': 'putting'}
# 2
# {'event_type': 'Justice:Arrest-Jail', 'arguments': [{'text': 'that guy', 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.06-2-E26-75'}, {'text': 'we', 'role': 'Agent', 'entity_id': 'CNN_CF_20030304.1900.06-2-E30-74'}], 'text': 'The way we caught that guy was by coordinating\nwith our allies', 'position': (691, 752), 'trigger': 'caught'}
# 2
# {'event_type': 'Justice:Arrest-Jail', 'arguments': [{'text': 'the guy', 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.06-2-E26-6'}, {'text': 'they', 'role': 'Agent', 'entity_id': 'CNN_CF_20030304.1900.06-2-E2-5'}, {'text': 'The same weekend', 'role': 'Time-Within', 'entity_id': 'CNN_CF_20030304.1900.06-2-T3-1'}], 'text': 'The same weekend they arrested the guy,\nwe had', 'position': (841, 886), 'trigger': 'arrested'}
# 2
# {'event_type': 'Justice:Arrest-Jail', 'arguments': [{'text': "al Qaeda's second key operative", 'role': 'Person', 'entity_id': 'CNN_CF_20030304.1900.06-2-E26-68'}], 'text': "And I'm curious, how\ncan Democrats claim that President Bush is ignoring the war on terror if\nal Qaeda's second key operative was just caught", 'position': (265, 405), 'trigger': 'caught'}
# 2
# {'event_type': 'Justice:Arrest-Jail', 'arguments': [], 'text': 'We had no part in it', 'position': (913, 932), 'trigger': 'it'}
# 2
# {'event_type': 'Justice:Arrest-Jail', 'arguments': [{'text': 'Pakistan', 'role': 'Agent', 'entity_id': 'CNN_CF_20030304.1900.06-2-E3-9'}], 'text': 'No, it was a joint effort by Pakistan', 'position': (946, 982), 'trigger': 'it'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'Iraq', 'role': 'Place', 'entity_id': 'CNN_CF_20030304.1900.06-2-E1-50'}], 'text': 'Why do we want to sever that\nrelationship with this idiotic war in Iraq', 'position': (985, 1055), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'we', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030304.1900.06-2-E30-29'}], 'text': 'The question of whether we go to war or not is\nstrictly a national question', 'position': (1452, 1526), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'On this Ash Wednesday, the pope\nasks Catholics to fast for peace and he asks President Bush to work for\npeace, while the White House sends out Colin Powell to make yet another\ncase for war', 'position': (262, 449), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "We don't need war", 'position': (1625, 1641), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "They're not pointing out that\ninspections are working only because there's the credible threat of war", 'position': (1644, 1744), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'American', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030305.1900.00-1-E25-76'}, {'text': 'Saddam\nHussein', 'role': 'Target', 'entity_id': 'CNN_CF_20030305.1900.00-1-E24-77'}], 'text': 'The essence of the American case for war against Saddam\nHussein', 'position': (3081, 3143), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "President Bush wants the Security\nCouncil to explicitly authorize force against Iraq, and his press\nsecretary today remained optimistic that in the end, that's just what\nhe'll get", 'position': (970, 1148), 'trigger': 'force'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'we', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030305.1900.00-1-E25-118'}], 'text': "It doesn't mean we have to go to war", 'position': (1887, 1922), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'But I\nthink President Bush should get credit for pushing to instructions and\nbacking them up with the threat of force', 'position': (1925, 2041), 'trigger': 'force'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "It means when you take the threat of force of the table, you're likely to\nstop disarming Saddam Hussein", 'position': (2056, 2158), 'trigger': 'force'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "Yes, I'm not saying take the threat of force", 'position': (2172, 2215), 'trigger': 'force'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'we', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030305.1900.00-1-E25-33'}], 'text': "I'm saying we don't need to\nuse force right now", 'position': (2218, 2264), 'trigger': 'force'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'Saddam', 'role': 'Target', 'entity_id': 'CNN_CF_20030305.1900.00-1-E24-48'}], 'text': "Saddam wouldn't be destroying missiles unless he thought he was going to\nbe destroyed if he didn't", 'position': (1747, 1844), 'trigger': 'destroyed'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'Phil Donahue', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.00-2-E4-71'}, {'text': 'the host of its highest-rated show', 'role': 'Position', 'entity_id': 'CNN_CF_20030305.1900.00-2-V1-1'}], 'text': 'Well, those of you who still believe the myth of the liberal media should\nconsider this: MSNBC, an obscure cable channel, has fired Phil Donahue,\nthe host of its highest-rated show', 'position': (204, 383), 'trigger': 'fired'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'Phil Donahue', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.00-2-E4-9'}], 'text': "Phil Donahue was fired because he's a liberal", 'position': (867, 911), 'trigger': 'fired'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'A memo from inside NBC, reported on\nthe Web site allyourtv.com, and today in "The Washington Post," shows NBC\nbig wigs feared that the liberal Mr. Donahue represented in the words of\nthe NBC memo -- quote -- "a difficult public face for NBC at a time of\nwar, while our competitors are waving the flag at every opportunity\nbecause he seems to delight in presenting guests who are anti-war,\nanti-Bush and skeptical of the administration\'s motives', 'position': (386, 829), 'trigger': 'war'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'someone', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.00-2-E15-36'}], 'text': "You know, you can argue back and forth, but you shouldn't fire someone\nbecause of their political views and that's what NBC has done and shame\non the General Electric corporation", 'position': (1495, 1672), 'trigger': 'fire'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'NBC', 'role': 'Entity', 'entity_id': 'CNN_CF_20030305.1900.00-2-E6-38'}], 'text': "You know, you can argue back and forth, but you shouldn't fire someone\nbecause of their political views and that's what NBC has done and shame\non the General Electric corporation", 'position': (1495, 1672), 'trigger': 'that'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'I', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.00-2-E10-43'}, {'text': 'there', 'role': 'Entity', 'entity_id': 'CNN_CF_20030305.1900.00-2-E18-44'}], 'text': 'I used to work there', 'position': (1766, 1785), 'trigger': 'work'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'a guy', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.00-2-E19-54'}, {'text': 'they', 'role': 'Entity', 'entity_id': 'CNN_CF_20030305.1900.00-2-E18-53'}], 'text': "but they shouldn't fire a guy for his political views", 'position': (1924, 1976), 'trigger': 'fire'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'Former Illinois Senator Carol Moseley-Braun', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.00-3-E23-1'}, {'text': 'Illinois', 'role': 'Place', 'entity_id': 'CNN_CF_20030305.1900.00-3-E37-72'}, {'text': 'Senator', 'role': 'Position', 'entity_id': 'CNN_CF_20030305.1900.00-3-V1-1'}], 'text': 'Former Illinois Senator Carol Moseley-Braun recently decided to run for\npresident', 'position': (205, 285), 'trigger': 'Former'}
# 2
# {'event_type': 'Personnel:Elect', 'arguments': [{'text': 'You', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.00-3-E17-25'}], 'text': 'You become honorable by winning an election of some sort or having a high\npost, being an ambassador or a governor or some thing', 'position': (1360, 1486), 'trigger': 'election'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'Saddam Hussein', 'role': 'Target', 'entity_id': 'CNN_CF_20030305.1900.00-3-E31-53'}], 'text': "In a moment, we'll ask two members of Congress if they're convinced that\nwar is the only way to make Saddam Hussein disarm", 'position': (1950, 2071), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'Later, the pope\npractices religion and a little anti-war politics on the side', 'position': (2074, 2150), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'we', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030305.1900.02-E14-55'}, {'text': 'al Qaeda', 'role': 'Target', 'entity_id': 'CNN_CF_20030305.1900.02-E26-56'}], 'text': 'Congressman Rangel, a couple of months ago Senator Daschle on CBS said --\nmade the charge that we are, quote, "we haven\'t made any real progress in\nthe war against al Qaeda', 'position': (1651, 1822), 'trigger': 'war'}
# 2
# {'event_type': 'Transaction:Transfer-Ownership', 'arguments': [{'text': 'them', 'role': 'Artifact', 'entity_id': 'CNN_CF_20030305.1900.02-E50-126'}, {'text': 'they', 'role': 'Buyer', 'entity_id': 'CNN_CF_20030305.1900.02-E90-125'}], 'text': "And how'd they get them", 'position': (3450, 3472), 'trigger': 'get'}
# 2
# {'event_type': 'Contact:Meet', 'arguments': [{'text': 'Secretary of State Colin Powell', 'role': 'Entity', 'entity_id': 'CNN_CF_20030305.1900.02-E86-212'}, {'text': 'the U.N', 'role': 'Entity', 'entity_id': 'CNN_CF_20030305.1900.02-E83-215'}, {'text': 'tomorrow', 'role': 'Time-Within', 'entity_id': 'CNN_CF_20030305.1900.02-T5-1'}], 'text': 'Secretary of State Colin Powell goes to\nthe U.N. tomorrow to do what he can', 'position': (374, 448), 'trigger': 'goes'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'Iraq', 'role': 'Place', 'entity_id': 'CNN_CF_20030305.1900.02-E90-218'}], 'text': "We're talking with potential war in\nIraq with Congressman Charlie Rangel, a New York Democrat and his fellow\nNew Yorker Republican Congressman Peter King", 'position': (451, 603), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'One of the reasons\nthat we like having you on, and as well as Mr. Rangel, is that, you know,\nthis is war, as we were saying in the last segment', 'position': (672, 814), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'You treat it with the\ngravity and the seriousness that it deserves', 'position': (817, 882), 'trigger': 'it'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "Isn't that wrong in a time of war", 'position': (1201, 1233), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'You treat it with the\ngravity and the seriousness that it deserves', 'position': (817, 882), 'trigger': 'it'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'One of the most\nadmired men in the world is doing everything he can to avert the horror\nof war', 'position': (4495, 4588), 'trigger': 'war'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'a former federal prosecutor', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.02-E1-79'}, {'text': 'federal prosecutor', 'role': 'Position', 'entity_id': 'CNN_CF_20030305.1900.02-V1-1'}, {'text': 'former', 'role': 'Time-Within', 'entity_id': 'CNN_CF_20030305.1900.02-T1-1'}], 'text': "If they don't have the pencil that's keeping score, they ought to keep\ntheir mouth shut because as a former federal prosecutor, every drug\ndealer I busted was the most important drug dealer in the world", 'position': (2261, 2462), 'trigger': 'former'}
# 2
# {'event_type': 'Justice:Arrest-Jail', 'arguments': [{'text': 'you', 'role': 'Agent', 'entity_id': 'CNN_CF_20030305.1900.02-E11-86'}, {'text': 'whoever you arrest', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.02-E76-200'}], 'text': 'You just\npass out numbers on whoever you arrest', 'position': (2465, 2511), 'trigger': 'arrest'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'the World Trade\nCenter', 'role': 'Target', 'entity_id': 'CNN_CF_20030305.1900.02-E42-92'}, {'text': 'the Pentagon', 'role': 'Target', 'entity_id': 'CNN_CF_20030305.1900.02-E43-93'}], 'text': 'Because he helped plan the attack on the World Trade\nCenter and the Pentagon', 'position': (2585, 2660), 'trigger': 'attack'}
# 2
# {'event_type': 'Justice:Arrest-Jail', 'arguments': [{'text': 'somebody', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.02-E44-101'}, {'text': 'you', 'role': 'Agent', 'entity_id': 'CNN_CF_20030305.1900.02-E41-97'}], 'text': "Let me tell you, when you arrest somebody, you describe who you're\narresting", 'position': (2744, 2819), 'trigger': 'arrest'}
# 2
# {'event_type': 'Justice:Arrest-Jail', 'arguments': [{'text': 'a lot of people', 'role': 'Person', 'entity_id': 'CNN_CF_20030305.1900.02-E49-115'}, {'text': 'we', 'role': 'Agent', 'entity_id': 'CNN_CF_20030305.1900.02-E14-114'}], 'text': 'Listen, we should be arresting a lot of people', 'position': (2988, 3033), 'trigger': 'arresting'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'we', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030305.1900.02-E14-119'}], 'text': 'We should do all of\nthose things, but the most important thing is we should not have the\narrogance to have a preemptive strike against a defenseless nation\nwithout the', 'position': (3178, 3344), 'trigger': 'strike'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'they', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030305.1900.02-E90-137'}, {'text': 'Iran', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030305.1900.02-E53-138'}], 'text': "They have it and we supported them having it when they\nwere fighting Iran so it's no big deal there", 'position': (3622, 3720), 'trigger': 'fighting'}
# 2
# {'event_type': 'Life:Die', 'arguments': [{'text': 'we', 'role': 'Agent', 'entity_id': 'CNN_CF_20030305.1900.02-E14-139'}, {'text': 'there', 'role': 'Place', 'entity_id': 'CNN_CF_20030305.1900.02-E90-141'}], 'text': 'And the thing is that if we\ncan disarm them without actually going there, killing them, I really\nthink that we maintain our moral authority around the world', 'position': (3723, 3878), 'trigger': 'killing'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'India', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030305.1900.02-E57-151'}], 'text': 'I mean, what happens if India decides\nthat they could have a preemptive strike against Pakistan', 'position': (3963, 4057), 'trigger': 'strike'}
# 2
# {'event_type': 'Life:Die', 'arguments': [{'text': 'we', 'role': 'Agent', 'entity_id': 'CNN_CF_20030305.1900.02-E14-159'}], 'text': "I don't think we have to kill\nto prove that", 'position': (4249, 4291), 'trigger': 'kill'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'That\nEurope is against the war on humanitarian and moral grounds, but the U.S.\nis for the war because it wants to profit for the oil companies', 'position': (1959, 2100), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "I think it's\nunwise, it's unjust, it's unwarranted, but I don't think it's about oil", 'position': (2285, 2368), 'trigger': 'it'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'The people are against it', 'position': (2469, 2493), 'trigger': 'it'}
# 2
# {'event_type': 'Contact:Phone-Write', 'arguments': [{'text': 'our wacky and\nkooky fans and friends and critics', 'role': 'Entity', 'entity_id': 'CNN_CF_20030305.1900.06-1-E24-77'}, {'text': 'our wacky and\nkooky fans and friends and critics', 'role': 'Entity', 'entity_id': 'CNN_CF_20030305.1900.06-1-E29-93'}, {'text': 'our wacky and\nkooky fans and friends and critics', 'role': 'Entity', 'entity_id': 'CNN_CF_20030305.1900.06-1-E30-94'}], 'text': 'Time now for "Fireback," where our wacky and\nkooky fans and friends and critics right in', 'position': (299, 386), 'trigger': 'right'}
# 2
# {'event_type': 'Contact:Phone-Write', 'arguments': [{'text': 'Don from Denver, Colorado', 'role': 'Entity', 'entity_id': 'CNN_CF_20030305.1900.06-1-E31-95'}], 'text': 'Don from Denver, Colorado\nwrites, "Paul, you keep referencing Halliburton selling equipment to\nIraq" -- which I do', 'position': (389, 502), 'trigger': 'writes'}
# 2
# {'event_type': 'Contact:Phone-Write', 'arguments': [{'text': 'Chad Hensley, from Fairfax, Virginia', 'role': 'Entity', 'entity_id': 'CNN_CF_20030305.1900.06-1-E7-80'}], 'text': 'Chad Hensley, from Fairfax, Virginia, writes,\n"France, Russia and German have all multi-billion dollar oil deals with\nSaddam in Iraq', 'position': (1701, 1832), 'trigger': 'writes'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'we', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030305.1900.06-1-E21-84'}, {'text': 'Iraq', 'role': 'Place', 'entity_id': 'CNN_CF_20030305.1900.06-1-E35-32'}], 'text': 'But it has nothing to\ndo whether we should go to war with Iraq or not', 'position': (1431, 1499), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'Iraq', 'role': 'Place', 'entity_id': 'CNN_CF_20030305.1900.06-1-E35-52'}], 'text': 'I wonder why they protest the war with Iraq', 'position': (1835, 1877), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'That\nEurope is against the war on humanitarian and moral grounds, but the U.S.\nis for the war because it wants to profit for the oil companies', 'position': (1959, 2100), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "I don't believe for a minute that this is a war for oil", 'position': (2228, 2282), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': 'Now, the reason that France, Russia and Germany are against war is\nbecause they have democracies', 'position': (2371, 2466), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'one of his valued customers', 'role': 'Target', 'entity_id': 'CNN_CF_20030305.1900.06-1-E5-22'}], 'text': "He's trying to lead us into a war against\none of his valued customers", 'position': (1126, 1194), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'Iraq', 'role': 'Place', 'entity_id': 'CNN_CF_20030305.1900.06-1-E35-16'}], 'text': 'What does that have to do with the war in Iraq', 'position': (1035, 1080), 'trigger': 'war'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'people who already hate Americans and seek to do\nAmerica harm', 'role': 'Attacker', 'entity_id': 'CNN_CF_20030305.1900.06-2-E35-80'}], 'text': 'On the other hand, the region is pretty\nunstable, filled with people who already hate Americans and seek to do\nAmerica harm', 'position': (592, 714), 'trigger': 'harm'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [], 'text': "And I\nwas just curious if you feel that the attack on Iraq would actually open\na Pandora's box in other Middle Eastern countries that we are known to\naid and harbor terrorists, such as Syria and Iran", 'position': (281, 479), 'trigger': 'attack'}
# 2
# ...
# 2
# {'event_type': 'Movement:Transport', 'arguments': [{'text': 'Turkish troops', 'role': 'Artifact', 'entity_id': 'APW_ENG_20030322.0119-E26-9'}, {'text': 'Turkish', 'role': 'Origin', 'entity_id': 'APW_ENG_20030322.0119-E94-231'}, {'text': 'Iraq', 'role': 'Destination', 'entity_id': 'APW_ENG_20030322.0119-E2-137'}, {'text': 'Saturday', 'role': 'Time-Before', 'entity_id': 'APW_ENG_20030322.0119-T4-1'}], 'text': 'A Turkish military spokesman on Saturday denied Turkish troops had\ncrossed into Iraq', 'position': (3317, 3400), 'trigger': 'crossed'}
# 2
# {'event_type': 'Life:Die', 'arguments': [{'text': 'two U.S. Marines\nkilled in combat', 'role': 'Victim', 'entity_id': 'APW_ENG_20030322.0119-E105-143'}, {'text': 'Thursday', 'role': 'Time-Within', 'entity_id': 'APW_ENG_20030322.0119-T5-1'}, {'text': 'Friday', 'role': 'Time-Within', 'entity_id': 'APW_ENG_20030322.0119-T6-1'}], 'text': 'The United States and Britain suffered their first casualties\nThursday and Friday as they pushed into Iraq, with two U.S. Marines\nkilled in combat and another eight British and four American Marines\ndying in a helicopter crash that appeared to be accidental', 'position': (3404, 3660), 'trigger': 'killed'}
# 2
# {'event_type': 'Life:Die', 'arguments': [{'text': 'helicopter', 'role': 'Instrument', 'entity_id': 'APW_ENG_20030322.0119-E165-151'}, {'text': 'another eight British and four American Marines\ndying in a helicopter crash that appeared to be accidental', 'role': 'Victim', 'entity_id': 'APW_ENG_20030322.0119-E110-150'}, {'text': 'Thursday', 'role': 'Time-Within', 'entity_id': 'APW_ENG_20030322.0119-T5-1'}, {'text': 'Friday', 'role': 'Time-Within', 'entity_id': 'APW_ENG_20030322.0119-T6-1'}], 'text': 'The United States and Britain suffered their first casualties\nThursday and Friday as they pushed into Iraq, with two U.S. Marines\nkilled in combat and another eight British and four American Marines\ndying in a helicopter crash that appeared to be accidental', 'position': (3404, 3660), 'trigger': 'dying'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'Australian commandos', 'role': 'Attacker', 'entity_id': 'APW_ENG_20030322.0119-E80-103'}, {'text': 'Iraq', 'role': 'Place', 'entity_id': 'APW_ENG_20030322.0119-E2-146'}, {'text': 'a command and control post', 'role': 'Target', 'entity_id': 'APW_ENG_20030322.0119-E112-147'}], 'text': "Australian commandos, who have been operating deep in Iraq, destroyed\na command and control post and killed a number of soldiers, according\nto the country's defense chief, Gen. Peter Cosgrove", 'position': (3711, 3901), 'trigger': 'destroyed'}
# 2
# {'event_type': 'Life:Die', 'arguments': [{'text': 'a number of soldiers', 'role': 'Victim', 'entity_id': 'APW_ENG_20030322.0119-E113-152'}, {'text': 'Australian commandos', 'role': 'Agent', 'entity_id': 'APW_ENG_20030322.0119-E80-103'}, {'text': 'Iraq', 'role': 'Place', 'entity_id': 'APW_ENG_20030322.0119-E2-146'}], 'text': "Australian commandos, who have been operating deep in Iraq, destroyed\na command and control post and killed a number of soldiers, according\nto the country's defense chief, Gen. Peter Cosgrove", 'position': (3711, 3901), 'trigger': 'killed'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'Saturday', 'role': 'Time-Before', 'entity_id': 'APW_ENG_20030322.0119-T7-1'}], 'text': 'In an address Saturday, Information Minister Mohammed Saeed al-Sahhaf\ntold Iraqis that fighting had been ``fierce', 'position': (3905, 4017), 'trigger': 'fighting'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'Iraqi troops', 'role': 'Attacker', 'entity_id': 'APW_ENG_20030322.0119-E188-168'}, {'text': 'five tanks', 'role': 'Target', 'entity_id': 'APW_ENG_20030322.0119-E125-170'}], 'text': 'He claimed\nIraqi troops had destroyed five tanks', 'position': (4100, 4147), 'trigger': 'destroyed'}
# 2
# {'event_type': 'Life:Injure', 'arguments': [{'text': 'women', 'role': 'Victim', 'entity_id': 'APW_ENG_20030322.0119-E127-172'}, {'text': 'children', 'role': 'Victim', 'entity_id': 'APW_ENG_20030322.0119-E128-173'}, {'text': 'other civilians', 'role': 'Victim', 'entity_id': 'APW_ENG_20030322.0119-E129-174'}, {'text': 'more than 200 Iraqis', 'role': 'Victim', 'entity_id': 'APW_ENG_20030322.0119-E190-262'}], 'text': 'He said more than 200 Iraqis\nhad been injured, including women, children and other civilians who\nwere being treated at five hospitals in Baghdad', 'position': (4151, 4294), 'trigger': 'injured'}
# 2
# {'event_type': 'Business:End-Org', 'arguments': [{'text': "Saddam's regime", 'role': 'Org', 'entity_id': 'APW_ENG_20030322.0119-E131-180'}], 'text': "Hoon said Saddam's regime was crumbling under the pressure of a huge\nair assault", 'position': (4298, 4377), 'trigger': 'crumbling'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': "Saddam's regime", 'role': 'Target', 'entity_id': 'APW_ENG_20030322.0119-E131-180'}], 'text': "Hoon said Saddam's regime was crumbling under the pressure of a huge\nair assault", 'position': (4298, 4377), 'trigger': 'assault'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'military command and control installations', 'role': 'Target', 'entity_id': 'APW_ENG_20030322.0119-E142-199'}], 'text': 'Despite the heavy bombing, which the U.S. Central Command said\ntargeted military command and control installations, the Iraqi regime\ngave no sign of quitting', 'position': (4976, 5132), 'trigger': 'bombing'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': "the\nnorthern cities of Mosul, Kirkuk and Tikrit, Saddam's hometown", 'role': 'Place', 'entity_id': 'APW_ENG_20030322.0119-E145-203'}, {'text': 'Mosul', 'role': 'Place', 'entity_id': 'APW_ENG_20030322.0119-E146-204'}, {'text': 'Kirkuk', 'role': 'Place', 'entity_id': 'APW_ENG_20030322.0119-E147-205'}, {'text': 'Tikrit', 'role': 'Place', 'entity_id': 'APW_ENG_20030322.0119-E148-206'}, {'text': 'Bombers', 'role': 'Instrument', 'entity_id': 'APW_ENG_20030322.0119-E144-202'}], 'text': "Bombers have also hit targets in the\nnorthern cities of Mosul, Kirkuk and Tikrit, Saddam's hometown", 'position': (5135, 5233), 'trigger': 'hit'}
# 2
# {'event_type': 'Contact:Meet', 'arguments': [{'text': 'the\ndefense minister', 'role': 'Entity', 'entity_id': 'APW_ENG_20030322.0119-E150-211'}, {'text': 'the commander of the Republican Guard', 'role': 'Entity', 'entity_id': 'APW_ENG_20030322.0119-E171-243'}], 'text': 'The Iraqi government released a video of Saddam, in uniform, meeting\nwith his son Qusai, the commander of the Republican Guard, and the\ndefense minister, Gen. Sultan Hashim Ahmad', 'position': (5237, 5414), 'trigger': 'meeting'}
# 2
# {'event_type': 'Contact:Phone-Write', 'arguments': [{'text': 'U.N. Secretary-General Kofi Annan', 'role': 'Entity', 'entity_id': 'APW_ENG_20030322.0119-E138-192'}, {'text': 'Ramadan', 'role': 'Entity', 'entity_id': 'APW_ENG_20030322.0119-E133-195'}], 'text': 'In a letter to U.N. Secretary-General Kofi Annan, Ramadan said, ``It\nis also regrettable and deplorable that the (U.N.) General\nSecretariat has not issued any statement or reaction that condemns or\ndeplores this aggression', 'position': (4749, 4970), 'trigger': 'letter'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'U.S. and British troops', 'role': 'Attacker', 'entity_id': 'APW_ENG_20030322.0119-E160-73'}, {'text': 'nearby Umm Qasr', 'role': 'Place', 'entity_id': 'APW_ENG_20030322.0119-E59-78'}], 'text': 'Until Basra, U.S. and British troops had encountered little\nresistance, even when they seized nearby Umm Qasr, and moved to\nsecure key oil fields', 'position': (1932, 2076), 'trigger': 'seized'}
# 2
# {'event_type': 'Conflict:Attack', 'arguments': [{'text': 'more units', 'role': 'Attacker', 'entity_id': 'APW_ENG_20030322.0119-E78-100'}, {'text': 'Kuwait', 'role': 'Place', 'entity_id': 'APW_ENG_20030322.0119-E45-101'}, {'text': 'Early Saturday', 'role': 'Time-Holds', 'entity_id': 'APW_ENG_20030322.0119-T18-1'}], 'text': 'Early Saturday, more units were waiting in Kuwait to smash through\nany Iraqi resistance', 'position': (2502, 2588), 'trigger': 'smash through'}
# 2
# {'event_type': 'Justice:Fine', 'arguments': [{'text': 'Gordon Campbell', 'role': 'Entity', 'entity_id': 'APW_ENG_20030324.0768-E7-30'}, {'text': '$913', 'role': 'Money', 'entity_id': 'APW_ENG_20030324.0768-V1-1'}], 'text': 'Gordon Campbell was ordered to pay fines and fees totaling $913,\ncomplete a 14-hour alcohol assessment program and have a substance\nabuse assessment', 'position': (280, 427), 'trigger': 'fines'}
# 2
# {'event_type': 'Justice:Fine', 'arguments': [{'text': 'Campbell', 'role': 'Entity', 'entity_id': 'APW_ENG_20030324.0768-E7-8'}], 'text': 'He also brought a\ncheck from Campbell to pay the fines and fees', 'position': (796, 858), 'trigger': 'fines'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'Campbell', 'role': 'Person', 'entity_id': 'APW_ENG_20030324.0768-E7-16'}, {'text': 'Vancouver', 'role': 'Place', 'entity_id': 'APW_ENG_20030324.0768-E6-15'}, {'text': 'British Columbians', 'role': 'Entity', 'entity_id': 'APW_ENG_20030324.0768-E9-21'}, {'text': 'premier', 'role': 'Position', 'entity_id': 'APW_ENG_20030324.0768-V4-1'}, {'text': 'two days\nlater', 'role': 'Time-At-End', 'entity_id': 'APW_ENG_20030324.0768-T6-1'}], 'text': 'In a tearful news conference after returning to Vancouver two days\nlater, Campbell apologized to British Columbians, but refused to\nresign as premier', 'position': (1202, 1350), 'trigger': 'resign'}
# 2
# {'event_type': 'Movement:Transport', 'arguments': [{'text': 'The premier of the western Canadian province of British Columbia', 'role': 'Artifact', 'entity_id': 'APW_ENG_20030324.0768-E7-1'}, {'text': 'Hawaiian', 'role': 'Destination', 'entity_id': 'APW_ENG_20030324.0768-E13-29'}, {'text': 'January', 'role': 'Time-Within', 'entity_id': 'APW_ENG_20030324.0768-T2-1'}], 'text': 'The premier of the western Canadian province of British Columbia\npleaded no contest to driving drunk during a Hawaiian vacation in\nJanuary', 'position': (139, 276), 'trigger': 'vacation'}
# 2
# {'event_type': 'Movement:Transport', 'arguments': [{'text': 'Campbell', 'role': 'Artifact', 'entity_id': 'APW_ENG_20030324.0768-E7-16'}, {'text': 'Vancouver', 'role': 'Destination', 'entity_id': 'APW_ENG_20030324.0768-E6-15'}, {'text': 'two days\nlater', 'role': 'Time-At-End', 'entity_id': 'APW_ENG_20030324.0768-T6-1'}], 'text': 'In a tearful news conference after returning to Vancouver two days\nlater, Campbell apologized to British Columbians, but refused to\nresign as premier', 'position': (1202, 1350), 'trigger': 'returning'}
# 2
# {'event_type': 'Life:Divorce', 'arguments': [{'text': 'his estranged wife', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E28-63'}, {'text': 'his', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E24-65'}], 'text': 'Retired General Electric Co. Chairman Jack Welch is seeking\nwork-related documents of his estranged wife in his high-stakes\ndivorce case', 'position': (149, 284), 'trigger': 'divorce'}
# 2
# {'event_type': 'Life:Divorce', 'arguments': [{'text': 'The Welches', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E29-66'}], 'text': 'The Welches disclosed their plans to divorce a year ago, shortly\nafter Suzy Wetlaufer  _  then editor of the Harvard Business Review \n_ revealed she had become romantically involved with Welch while\nworking on a story about him', 'position': (288, 514), 'trigger': 'divorce'}
# 2
# {'event_type': 'Life:Divorce', 'arguments': [], 'text': 'A judge ruled in February that depositions in the divorce case will\nremain confidential', 'position': (1330, 1416), 'trigger': 'divorce'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'Retired General Electric Co. Chairman Jack Welch', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E24-60'}, {'text': 'General Electric Co', 'role': 'Entity', 'entity_id': 'APW_ENG_20030325.0786-E26-62'}, {'text': 'Chairman', 'role': 'Position', 'entity_id': 'APW_ENG_20030325.0786-V4-1'}], 'text': 'Retired General Electric Co. Chairman Jack Welch is seeking\nwork-related documents of his estranged wife in his high-stakes\ndivorce case', 'position': (149, 284), 'trigger': 'Retired'}
# 2
# {'event_type': 'Life:Marry', 'arguments': [{'text': 'she', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E28-18'}, {'text': 'Welch', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E24-19'}], 'text': "He\nalso wants to subpoena all documents maintained in Jane Beasley\nWelch's personnel file by Shearman & Sterling, a prestigious\ncorporate law firm where she worked before she married Welch", 'position': (718, 909), 'trigger': 'married'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'Jane Beasley Welch', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E28-30'}], 'text': "Welch also wants details on Jane Beasley Welch's salary, benefits,\nretirement plan and other compensation paid to her", 'position': (1139, 1255), 'trigger': 'retirement'}
# 2
# {'event_type': 'Personnel:Start-Position', 'arguments': [{'text': 'her', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E28-27'}, {'text': 'the law\nfirm', 'role': 'Entity', 'entity_id': 'APW_ENG_20030325.0786-E6-25'}, {'text': 'a partner', 'role': 'Position', 'entity_id': 'APW_ENG_20030325.0786-V5-1'}], 'text': "Welch specifically is seeking performance evaluations, correspondence\nbetween his estranged wife and partners while she worked at the law\nfirm's office in London, and documents related to her prospects of\nbecoming a partner", 'position': (913, 1135), 'trigger': 'becoming'}
# 2
# {'event_type': 'Life:Marry', 'arguments': [{'text': 'the Welches', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E29-50'}], 'text': "Webb also said details of the breakdowns of the Welches' previous\nmarriages were likely to come up, and cited reports of alleged\nextramarital affairs by both", 'position': (1797, 1953), 'trigger': 'marriages'}
# 2
# {'event_type': 'Life:Divorce', 'arguments': [{'text': 'the Welches', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E29-50'}], 'text': "Webb also said details of the breakdowns of the Welches' previous\nmarriages were likely to come up, and cited reports of alleged\nextramarital affairs by both", 'position': (1797, 1953), 'trigger': 'breakdowns'}
# 2
# {'event_type': 'Contact:Phone-Write', 'arguments': [{'text': "the law\nfirm's office in London", 'role': 'Place', 'entity_id': 'APW_ENG_20030325.0786-E9-24'}, {'text': 'his estranged wife', 'role': 'Entity', 'entity_id': 'APW_ENG_20030325.0786-E28-21'}, {'text': 'partners', 'role': 'Entity', 'entity_id': 'APW_ENG_20030325.0786-E8-22'}], 'text': "Welch specifically is seeking performance evaluations, correspondence\nbetween his estranged wife and partners while she worked at the law\nfirm's office in London, and documents related to her prospects of\nbecoming a partner", 'position': (913, 1135), 'trigger': 'correspondence'}
# 2
# {'event_type': 'Transaction:Transfer-Money', 'arguments': [{'text': 'Jane Beasley Welch', 'role': 'Recipient', 'entity_id': 'APW_ENG_20030325.0786-E28-30'}], 'text': "Welch also wants details on Jane Beasley Welch's salary, benefits,\nretirement plan and other compensation paid to her", 'position': (1139, 1255), 'trigger': 'paid'}
# 2
# {'event_type': 'Personnel:End-Position', 'arguments': [{'text': 'Welch', 'role': 'Person', 'entity_id': 'APW_ENG_20030325.0786-E24-38'}, {'text': 'GE', 'role': 'Entity', 'entity_id': 'APW_ENG_20030325.0786-E26-40'}], 'text': 'Earlier documents in the case have included embarrassing details\nabout perks Welch received as part of his retirement package from GE\nat a time when corporate scandals were sparking outrage', 'position': (1420, 1608), 'trigger': 'retirement'}
# 2
